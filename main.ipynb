# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('avocado.csv')
print(df)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
plt.hist(df['AveragePrice'])
plt.title('Average Price')
plt.xlabel('Dollars')
plt.ylabel('Frequency')
plt.show()

# %%
# from matplotlib.pyplot import figure

# figure(figsize=(10, 8), dpi=80)
plt.hist(df['4046'], color='red')
plt.title('PLU 4046')
plt.xlabel('Number of Avocados Sold')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['4225'], color='pink')
plt.title('PLU 4225')
plt.xlabel('Number of Avocados Sold')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['4770'], color='green')
plt.title('PLU 4770')
plt.xlabel('Number of Avocados Sold')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Total Volume'], color='yellow')
plt.title('Total Volume')
plt.xlabel('Number of Avocados Sold')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
lst = ['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'year']
corrMatrix = df[lst].corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
cat_vars = ['region', 'type']
for var in cat_vars:
  cat_list = pd.get_dummies(df[var], prefix=var)
  df = df.join(cat_list, lsuffix='noMore')

# %%
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
